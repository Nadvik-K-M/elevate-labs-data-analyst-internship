# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
slots = pd.read_csv("C:\\Users\\Admin\\Documents\\slots.csv")

# %%
slots
# Out:
#                                 Unique_id         AD_ID    Air Date  Air Time  \
# 0     SPYMYA2MC009416440.0479166666666667  SPYMYA2MC009  01-05-2014   1:09 AM
# 1     SPYMYA60A010416440.0534722222222222  SPYMYA60A010  01-05-2014   1:17 AM
# 2     SPYMYA60A030416440.0631944444444444  SPYMYA60A030  01-05-2014   1:31 AM
# 3     SPYMYA2MC031416440.0743055555555556  SPYMYA2MC031  01-05-2014   1:47 AM
# 4     SPYMYA2ME010416440.0743055555555556  SPYMYA2ME010  01-05-2014   1:47 AM
# ...                                   ...           ...         ...       ...
# 1759   SPYMYA2MC061416640.944444444444445  SPYMYA2MC061   1/25/2014  10:40 PM
# 1760   MYSPYR60A004416640.951388888888889  MYSPYR60A004   1/25/2014  10:50 PM
# 1761   SPYMYA60B014416640.965972222222222  SPYMYA60B014   1/25/2014  11:11 PM
# 1762               MYSPYR60A004416640.975  MYSPYR60A004   1/25/2014  11:24 PM
# 1763   SPYMYA2MC061416640.977083333333333  SPYMYA2MC061   1/25/2014  11:27 PM
#
# ...

# %%
slots.head()
# Out:
#                              Unique_id         AD_ID    Air Date Air Time  \
# 0  SPYMYA2MC009416440.0479166666666667  SPYMYA2MC009  01-05-2014  1:09 AM
# 1  SPYMYA60A010416440.0534722222222222  SPYMYA60A010  01-05-2014  1:17 AM
# 2  SPYMYA60A030416440.0631944444444444  SPYMYA60A030  01-05-2014  1:31 AM
# 3  SPYMYA2MC031416440.0743055555555556  SPYMYA2MC031  01-05-2014  1:47 AM
# 4  SPYMYA2ME010416440.0743055555555556  SPYMYA2ME010  01-05-2014  1:47 AM
#
#   Time Zone Client Product Code Product ID  Length Network ID Network Name  \
# 0       EST              MSDR02     SPYMYA     120       TRAV       Travel
# 1       EST              MSDR02     SPYMYA      60        DIY          DIY
# 2       EST              MSDR02     SPYMYA      60       TRAV       Travel
# 3       EST              MSDR02     SPYMYA     120        BIO    Biography
# 4       EST              MSDR02     SPYMYA     120       TNNK     TeenNick
#
# ...

# %%
slots.tail()
# Out:
#                                Unique_id         AD_ID   Air Date  Air Time  \
# 1759  SPYMYA2MC061416640.944444444444445  SPYMYA2MC061  1/25/2014  10:40 PM
# 1760  MYSPYR60A004416640.951388888888889  MYSPYR60A004  1/25/2014  10:50 PM
# 1761  SPYMYA60B014416640.965972222222222  SPYMYA60B014  1/25/2014  11:11 PM
# 1762              MYSPYR60A004416640.975  MYSPYR60A004  1/25/2014  11:24 PM
# 1763  SPYMYA2MC061416640.977083333333333  SPYMYA2MC061  1/25/2014  11:27 PM
#
#      Time Zone Client Product Code Product ID  Length Network ID  \
# 1759       EST              MSDR02     SPYMYA     120       KCDO
# 1760       EST             MSDR02R     MYSPYR      60       NHLN
# 1761       EST              MSDR02     SPYMYA      60     MILLOC
# 1762       EST             MSDR02R     MYSPYR      60       NHLN
# 1763       EST              MSDR02     SPYMYA     120       KCDO
#
#                        Network Name        Network Type Network DMA  \
# ...

# %%
slots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1764 entries, 0 to 1763
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unique_id             1764 non-null   object
#  1   AD_ID                 1764 non-null   object
#  2   Air Date              1764 non-null   object
#  3   Air Time              1761 non-null   object
#  4   Time Zone             1764 non-null   object
#  5   Client Product Code   1764 non-null   object
#  6   Product ID            1764 non-null   object
#  7   Length                1764 non-null   int64
#  8   Network ID            1764 non-null   object
#  9   Network Name          1764 non-null   object
#  10  Network Type          1761 non-null   object
#  11  Network DMA           1747 non-null   object
#  12  Network Feed          1325 non-null   object
#  13  HH Impressions        1211 non-null   float64
#  14  HH Ratings            1211 non-null   float64
# ...

# %%
slots.describe()
# Out:
#             Length  HH Impressions   HH Ratings    Spot Cost  \
# count  1764.000000     1211.000000  1211.000000  1742.000000
# mean     80.102041      225.033031     0.194377   122.623995
# std      28.328172      588.504563     0.508290   338.594250
# min      60.000000        0.000000     0.000000     0.000000
# 25%      60.000000       74.000000     0.060000    20.000000
# 50%      60.000000      140.000000     0.120000    50.000000
# 75%     120.000000      234.000000     0.200000   100.000000
# max     120.000000    18418.000000    15.910000  5800.000000
#
#        Spot Cost Discounted
# count           1764.000000
# mean             115.039938
# std              319.912732
# min                0.000000
# 25%               19.000000
# 50%               47.500000
# 75%               95.000000
# max             5510.000000

# %%
#null values
missing_values = slots.isnull().sum()
print("Missing values ",missing_values)

col_missing_values = slots["HH Impressions"].isnull().sum()
print(" \n Missing values for HH Impressions ",col_missing_values)
# Out:
# Missing values  Unique_id                 0
# AD_ID                     0
# Air Date                  0
# Air Time                  3
# Time Zone                 0
# Client Product Code       0
# Product ID                0
# Length                    0
# Network ID                0
# Network Name              0
# Network Type              3
# Network DMA              17
# Network Feed            439
# HH Impressions          553
# HH Ratings              553
# Spot Cost                22
# Spot Cost Discounted      0
# dtype: int64
#
#  Missing values for HH Impressions  553

# %%
#Percentage wise Null values
NetworkType = slots['Network Type'].isnull().sum()/slots.shape[0]*100
NetworkFeed = slots['Network Feed'].isnull().sum()/slots.shape[0]*100
HHImpressions = slots['HH Impressions'].isnull().sum()/slots.shape[0]*100
HHRatings = slots['HH Ratings'].isnull().sum()/slots.shape[0]*100
print(f"Null values Percentage are:  \n 1 NetworkType = {NetworkType} \n 2 NetworkFeed = {NetworkFeed} \n 3 HHImpressions = {HHImpressions}\n 4 HHRatings  {HHRatings} ")
# Out:
# Null values Percentage are:
#  1 NetworkType = 0.17006802721088435
#  2 NetworkFeed = 24.886621315192745
#  3 HHImpressions = 31.349206349206348
#  4 HHRatings  31.349206349206348

# %%
slots.columns
# Out:
# Index(['Unique_id', 'AD_ID', 'Air Date', 'Air Time', 'Time Zone',
#        'Client Product Code', 'Product ID', 'Length', 'Network ID',
#        'Network Name', 'Network Type', 'Network DMA', 'Network Feed',
#        'HH Impressions', 'HH Ratings', 'Spot Cost', 'Spot Cost Discounted'],
#       dtype='object')

# %%
#Remove Extra Space
slots.columns.str.strip()
# Out:
# Index(['Unique_id', 'AD_ID', 'Air Date', 'Air Time', 'Time Zone',
#        'Client Product Code', 'Product ID', 'Length', 'Network ID',
#        'Network Name', 'Network Type', 'Network DMA', 'Network Feed',
#        'HH Impressions', 'HH Ratings', 'Spot Cost', 'Spot Cost Discounted'],
#       dtype='object')

# %%
slots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1764 entries, 0 to 1763
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unique_id             1764 non-null   object
#  1   AD_ID                 1764 non-null   object
#  2   Air Date              1764 non-null   object
#  3   Air Time              1761 non-null   object
#  4   Time Zone             1764 non-null   object
#  5   Client Product Code   1764 non-null   object
#  6   Product ID            1764 non-null   object
#  7   Length                1764 non-null   int64
#  8   Network ID            1764 non-null   object
#  9   Network Name          1764 non-null   object
#  10  Network Type          1761 non-null   object
#  11  Network DMA           1747 non-null   object
#  12  Network Feed          1325 non-null   object
#  13  HH Impressions        1211 non-null   float64
#  14  HH Ratings            1211 non-null   float64
# ...

# %%
slots_cleaned = slots.drop_duplicates()
slots_cleaned
# Out:
#                                 Unique_id         AD_ID    Air Date  Air Time  \
# 0     SPYMYA2MC009416440.0479166666666667  SPYMYA2MC009  01-05-2014   1:09 AM
# 1     SPYMYA60A010416440.0534722222222222  SPYMYA60A010  01-05-2014   1:17 AM
# 2     SPYMYA60A030416440.0631944444444444  SPYMYA60A030  01-05-2014   1:31 AM
# 3     SPYMYA2MC031416440.0743055555555556  SPYMYA2MC031  01-05-2014   1:47 AM
# 4     SPYMYA2ME010416440.0743055555555556  SPYMYA2ME010  01-05-2014   1:47 AM
# ...                                   ...           ...         ...       ...
# 1759   SPYMYA2MC061416640.944444444444445  SPYMYA2MC061   1/25/2014  10:40 PM
# 1760   MYSPYR60A004416640.951388888888889  MYSPYR60A004   1/25/2014  10:50 PM
# 1761   SPYMYA60B014416640.965972222222222  SPYMYA60B014   1/25/2014  11:11 PM
# 1762               MYSPYR60A004416640.975  MYSPYR60A004   1/25/2014  11:24 PM
# 1763   SPYMYA2MC061416640.977083333333333  SPYMYA2MC061   1/25/2014  11:27 PM
#
# ...

# %%
# Filling Null Values with mean and Mode
air_time = slots['Air Time'].mode()
slots['Air Time'].fillna(air_time[0],inplace = True)

network_type = slots['Network Type'].mode()
slots['Network Type'].fillna(network_type[0],inplace = True)

Network_DMA = slots['Network DMA'].mode()
slots['Network DMA'].fillna(Network_DMA[0],inplace = True)

Network_Feed = slots['Network Feed'].mode()
slots['Network Feed'].fillna(Network_Feed[0],inplace = True)

# %%
HH_Impressions = slots['HH Impressions'].mean()
slots['HH Impressions'].fillna(HH_Impressions,inplace = True)

HH_Ratings  = slots['HH Ratings'].mean()
slots['HH Ratings'].fillna(HH_Ratings,inplace = True)

Spot_Cost  = slots['Spot Cost'].mean()
slots['Spot Cost'].fillna(Spot_Cost,inplace = True)

# %%
slots.isnull().sum()
# Out:
# Unique_id               0
# AD_ID                   0
# Air Date                0
# Air Time                0
# Time Zone               0
# Client Product Code     0
# Product ID              0
# Length                  0
# Network ID              0
# Network Name            0
# Network Type            0
# Network DMA             0
# Network Feed            0
# HH Impressions          0
# HH Ratings              0
# Spot Cost               0
# Spot Cost Discounted    0
# dtype: int64

# %%
slots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1764 entries, 0 to 1763
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unique_id             1764 non-null   object
#  1   AD_ID                 1764 non-null   object
#  2   Air Date              1764 non-null   object
#  3   Air Time              1764 non-null   object
#  4   Time Zone             1764 non-null   object
#  5   Client Product Code   1764 non-null   object
#  6   Product ID            1764 non-null   object
#  7   Length                1764 non-null   int64
#  8   Network ID            1764 non-null   object
#  9   Network Name          1764 non-null   object
#  10  Network Type          1764 non-null   object
#  11  Network DMA           1764 non-null   object
#  12  Network Feed          1764 non-null   object
#  13  HH Impressions        1764 non-null   float64
#  14  HH Ratings            1764 non-null   float64
# ...

# %%
slots.boxplot(figsize = [16,8])
# Out:
# <Axes: >

# %%
slots.columns
# Out:
# Index(['Unique_id', 'AD_ID', 'Air Date', 'Air Time', 'Time Zone',
#        'Client Product Code', 'Product ID', 'Length', 'Network ID',
#        'Network Name', 'Network Type', 'Network DMA', 'Network Feed',
#        'HH Impressions', 'HH Ratings', 'Spot Cost', 'Spot Cost Discounted'],
#       dtype='object')

# %%
sns.boxplot(slots['Length'])
plt.show()

# %%
ub_Len = slots['Length'].quantile(0.75) +1.5*(slots['Length'].quantile(0.75)-slots['Length'].quantile(0.25))
slots['Length'] = np.where(slots['Length']>ub_Len,ub_Len,slots['Length'])

# %%
sns.boxplot(slots['Length'])
plt.show()

# %%
sns.boxplot(slots['HH Ratings'])
plt.show()

# %%
ub_HR = slots['HH Ratings'].quantile(0.75) +1.5*(slots['HH Ratings'].quantile(0.75)-slots['HH Ratings'].quantile(0.25))
slots['HH Ratings'] = np.where(slots['HH Ratings']>ub_HR,ub_HR,slots['HH Ratings'])

# %%
sns.boxplot(slots['HH Ratings'])
plt.show()
